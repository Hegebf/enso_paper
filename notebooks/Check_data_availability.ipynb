# %% [markdown]
# # Data availability

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from scipy.signal import detrend
from matplotlib import pyplot as plt
from scipy import signal
import pandas as pd
import xarray as xr
import intake
import pprint 
import util

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_datastore("../catalogs/pangeo-cmip6.json")
col;

# %%
exp_list = ['piControl', 'historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585', 'abrupt-4xCO2']

df = pd.DataFrame()
for chosen_exp in exp_list:
    print(chosen_exp)
    cat = col.search(experiment_id = chosen_exp, variable_id='ts', table_id='Amon')
    
    # the following code removes models that causes errors in .to_dataset_dict:
    uni_dict = cat.unique(['source_id'])
    models = uni_dict['source_id']['values']; 
    source_ids = models[:]
    if chosen_exp == 'ssp126':
        remove_models = ['EC-Earth3'] # EC-Earth3_ssp126_r15i1p1f1 is missing many years
    elif chosen_exp == 'ssp245':
        remove_models = ['UKESM1-0-LL', 'EC-Earth3'] # UKESM1-0-LL_ssp245_r8i1p1f2 causes error that I don't understand
    else:
        remove_models = []
    for mod in remove_models:
        source_ids.remove(mod) # remove models
        df.loc[mod, chosen_exp + ' (ens.mem.)'] = 'data problem'
    # load new table without the problematic models:
    cat = col.search(source_id = source_ids, experiment_id = chosen_exp, variable_id='ts', table_id='Amon')
    
    
    dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True}, cdf_kwargs={'chunks': {}})
    keys = []
    for key in dset_dict.keys():
        keys.append(key)

    for key in keys:
        ds = dset_dict[key]
        model = ds.source_id
        start_time = str(ds['time'][0].values)[:7]
        end_time = str(ds['time'][-1].values)[:7]
        run_length = int(end_time[:4]) + 1 - int(start_time[:4])
        df.loc[model,chosen_exp + ' (yrs)'] = run_length
        df.loc[model,chosen_exp + ' (ens.mem.)'] = ds.member_id.size # number of ensemble members
# Out:
# piControl
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 28 group(s)
# historical
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 26 group(s)
# ssp126
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 15 group(s)
# ssp245
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 16 group(s)
# ssp370
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 16 group(s)
# ssp585
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 17 group(s)
# abrupt-4xCO2
#
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 22 group(s)

# %%
column_names = list(df.columns);
yr_cols = [col for col in column_names if col[-5:] == '(yrs)']
ens_cols = [col for col in column_names if col[-10:] == '(ens.mem.)']
df2 = df[ens_cols + yr_cols]
df2
#df2.to_csv('available_data.txt', sep='\t')
# Out:
#                  piControl (ens.mem.)  historical (ens.mem.)  \
# BCC-CSM2-MR                       1.0                    3.0
# BCC-ESM1                          1.0                    3.0
# CAMS-CSM1-0                       1.0                    2.0
# FGOALS-g3                         1.0                    3.0
# CanESM5                           2.0                   44.0
# CNRM-CM6-1                        1.0                   14.0
# CNRM-ESM2-1                       1.0                    5.0
# E3SM-1-0                          1.0                    5.0
# EC-Earth3                         1.0                   12.0
# EC-Earth3-Veg                     1.0                    4.0
# FIO-ESM-2-0                       1.0                    NaN
# IPSL-CM6A-LR                      2.0                   32.0
# MIROC-ES2L                        1.0                    1.0
# MIROC6                            1.0                   10.0
# HadGEM3-GC31-LL                   1.0                    4.0
# HadGEM3-GC31-MM                   1.0                    NaN
# UKESM1-0-LL                       1.0                    9.0
# MRI-ESM2-0                        1.0                    5.0
# GISS-E2-1-G                       6.0                   22.0
# GISS-E2-1-H                       1.0                   10.0
# CESM2                             1.0                   11.0
# CESM2-WACCM                       1.0                    3.0
# NorESM2-LM                        1.0                    1.0
# GFDL-CM4                          1.0                    1.0
# GFDL-ESM4                         1.0                    1.0
# NESM3                             1.0                    4.0
# SAM0-UNICON                       1.0                    1.0
# MCM-UA-1-0                        1.0                    1.0
# MPI-ESM1-2-HR                     NaN                    NaN
#
#                 ssp126 (ens.mem.) ssp245 (ens.mem.)  ssp370 (ens.mem.)  \
# BCC-CSM2-MR                   NaN                 1                NaN
# BCC-ESM1                      NaN               NaN                3.0
# CAMS-CSM1-0                     1                 1                1.0
# FGOALS-g3                       1                 1                1.0
# CanESM5                        34                38               43.0
# CNRM-CM6-1                      4                 5                6.0
# CNRM-ESM2-1                     5                 3                3.0
# E3SM-1-0                      NaN               NaN                NaN
# EC-Earth3            data problem      data problem                7.0
# EC-Earth3-Veg                   3                 3                3.0
# FIO-ESM-2-0                   NaN               NaN                NaN
# IPSL-CM6A-LR                    1                 1                9.0
# MIROC-ES2L                      1               NaN                NaN
# MIROC6                          2                 3                2.0
# HadGEM3-GC31-LL               NaN                 2                NaN
# HadGEM3-GC31-MM               NaN               NaN                NaN
# UKESM1-0-LL                     5      data problem                4.0
# MRI-ESM2-0                    NaN                 4                4.0
# GISS-E2-1-G                   NaN               NaN                NaN
# GISS-E2-1-H                   NaN               NaN                NaN
# CESM2                           1                 1                2.0
# CESM2-WACCM                     1                 1                3.0
# NorESM2-LM                    NaN               NaN                NaN
# GFDL-CM4                      NaN               NaN                NaN
# GFDL-ESM4                       1                 1                1.0
# NESM3                           1                 2                NaN
# SAM0-UNICON                   NaN               NaN                NaN
# MCM-UA-1-0                    NaN               NaN                NaN
# MPI-ESM1-2-HR                   1                 1               10.0
#
#                  ssp585 (ens.mem.)  abrupt-4xCO2 (ens.mem.)  piControl (yrs)  \
# BCC-CSM2-MR                    1.0                      1.0            600.0
# BCC-ESM1                       NaN                      1.0            451.0
# CAMS-CSM1-0                    1.0                      2.0            250.0
# FGOALS-g3                      1.0                      NaN            670.0
# CanESM5                       42.0                      2.0           1000.0
# CNRM-CM6-1                     5.0                      6.0            500.0
# CNRM-ESM2-1                    3.0                      3.0            500.0
# E3SM-1-0                       NaN                      1.0            500.0
# EC-Earth3                      6.0                      NaN            501.0
# EC-Earth3-Veg                  3.0                      1.0            496.0
# FIO-ESM-2-0                    NaN                      NaN            400.0
# IPSL-CM6A-LR                   NaN                     12.0           1200.0
# MIROC-ES2L                     1.0                      NaN            500.0
# MIROC6                         1.0                      1.0            800.0
# HadGEM3-GC31-LL                NaN                      1.0            400.0
# HadGEM3-GC31-MM                NaN                      NaN            460.0
# UKESM1-0-LL                    5.0                      1.0            750.0
# MRI-ESM2-0                     1.0                     13.0            701.0
# GISS-E2-1-G                    NaN                      3.0           6001.0
# GISS-E2-1-H                    NaN                      1.0            801.0
# CESM2                          2.0                      1.0           1200.0
# CESM2-WACCM                    1.0                      1.0            499.0
# NorESM2-LM                     NaN                      1.0            301.0
# GFDL-CM4                       1.0                      1.0            500.0
# GFDL-ESM4                      NaN                      NaN            400.0
# NESM3                          2.0                      1.0            200.0
# SAM0-UNICON                    NaN                      1.0            700.0
# MCM-UA-1-0                     NaN                      1.0            300.0
# MPI-ESM1-2-HR                  1.0                      NaN              NaN
#
#                  historical (yrs)  ssp126 (yrs)  ssp245 (yrs)  ssp370 (yrs)  \
# BCC-CSM2-MR                 165.0           NaN          86.0           NaN
# BCC-ESM1                    165.0           NaN           NaN          41.0
# CAMS-CSM1-0                 165.0          85.0          85.0          85.0
# FGOALS-g3                   167.0          86.0          80.0          81.0
# CanESM5                     165.0         286.0          86.0          86.0
# CNRM-CM6-1                  165.0          86.0          86.0          86.0
# CNRM-ESM2-1                 165.0          86.0          86.0          86.0
# E3SM-1-0                    165.0           NaN           NaN           NaN
# EC-Earth3                   166.0           NaN           NaN          86.0
# EC-Earth3-Veg               165.0          86.0          86.0          86.0
# FIO-ESM-2-0                   NaN           NaN           NaN           NaN
# IPSL-CM6A-LR                165.0          86.0          86.0          86.0
# MIROC-ES2L                  165.0          86.0           NaN           NaN
# MIROC6                      165.0          86.0          86.0          86.0
# HadGEM3-GC31-LL             165.0           NaN          86.0           NaN
# HadGEM3-GC31-MM               NaN           NaN           NaN           NaN
# UKESM1-0-LL                 165.0          86.0           NaN          86.0
# MRI-ESM2-0                  165.0           NaN          16.0          86.0
# GISS-E2-1-G                 165.0           NaN           NaN           NaN
# GISS-E2-1-H                 165.0           NaN           NaN           NaN
# CESM2                       165.0          86.0          86.0          86.0
# CESM2-WACCM                 165.0          86.0          86.0          86.0
# NorESM2-LM                  165.0           NaN           NaN           NaN
# GFDL-CM4                    165.0           NaN           NaN           NaN
# GFDL-ESM4                   165.0          86.0          86.0          86.0
# NESM3                       165.0          86.0          86.0           NaN
# SAM0-UNICON                 165.0           NaN           NaN           NaN
# MCM-UA-1-0                  165.0           NaN           NaN           NaN
# MPI-ESM1-2-HR                 NaN          81.0          86.0          86.0
#
#                  ssp585 (yrs)  abrupt-4xCO2 (yrs)
# BCC-CSM2-MR              86.0               151.0
# BCC-ESM1                  NaN               151.0
# CAMS-CSM1-0              85.0               155.0
# FGOALS-g3                81.0                 NaN
# CanESM5                 166.0               151.0
# CNRM-CM6-1               86.0                10.0
# CNRM-ESM2-1              86.0               150.0
# E3SM-1-0                  NaN               125.0
# EC-Earth3                86.0                 NaN
# EC-Earth3-Veg            86.0               151.0
# FIO-ESM-2-0               NaN                 NaN
# IPSL-CM6A-LR              NaN               900.0
# MIROC-ES2L               86.0                 NaN
# MIROC6                   86.0               250.0
# HadGEM3-GC31-LL           NaN               150.0
# HadGEM3-GC31-MM           NaN                 NaN
# UKESM1-0-LL              86.0               150.0
# MRI-ESM2-0               86.0               151.0
# GISS-E2-1-G               NaN              1150.0
# GISS-E2-1-H               NaN               151.0
# CESM2                    86.0               999.0
# CESM2-WACCM              86.0               150.0
# NorESM2-LM                NaN               300.0
# GFDL-CM4                 86.0               100.0
# GFDL-ESM4                 NaN                 NaN
# NESM3                    86.0               150.0
# SAM0-UNICON               NaN               150.0
# MCM-UA-1-0                NaN               500.0
# MPI-ESM1-2-HR            86.0                 NaN
